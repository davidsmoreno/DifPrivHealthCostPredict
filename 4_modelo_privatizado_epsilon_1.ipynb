# %% [markdown]
# # Modelo Privatizado con epsilon 1

# %% [markdown]
# Utilizando la base privatizada con laplace y OUE con un epsilon tomando valor igual a  1 (su obtención se da con el archivo 2_Analisis_Exploratorio) se procede a crear modelo con el fin de comparar.

# %%
import pickle
import pandas as pd

archivo_pickle = 'base_epsilon_1.0.pkl'


with open(archivo_pickle, 'rb') as file:
    df = pickle.load(file)

# %% [markdown]
# Como se hizo en el modelo sin privatizar se trabajara el con personas que tengan una enfermedad, excuyendo asi a los sanos

# %%
df = df[df['Enfermedad'] != 'Sin Enfermedad']

# %% [markdown]
# Se vio en el procedimiento de la privatización que juntamos todas las enfermedades separando por , pero para el modelamiento se necesita volver a ampliar la base, dummificando la enfermedad.

# %%
df['Enfermedad'] = df['Enfermedad'].str.split(',')

# Crear variables dummies
enfermedades_dummies = df['Enfermedad'].str.join('|').str.get_dummies()

# %%
df = pd.concat([df.drop('Enfermedad', axis=1), enfermedades_dummies], axis=1)

# %% [markdown]
# Se eliminan las filas donde no se nos aporta la información ya que vienen en 0 y las columnas que no son relevantes para el modelo.

# %%
# Eliminar columnas donde todas las entradas son cero
df = df.loc[:, (df != 0).any(axis=0)]
df['DIAS_COMP'] = df['DIAS_COMP'].astype(float)
df.drop(columns='MUNI', inplace=True)

# %% [markdown]
# Se seleccionan varias variables categóricas, específicamente 'EPS', 'SEXO', 'DPTO', 'V8', 'Grupo_Edad', 'Zona', para aplicarles el proceso de One-Hot Encoding, con el fin de transformarlas en formatos adecuados, garantizando que el dataset solo contenga variables numéricas. Finalmente, se define 'Valor_Neto' como la variable objetivo del estudio y se procede a dividir el dataset en conjuntos de entrenamiento y prueba, asignando el 25% de los datos al conjunto de prueba, utilizando un estado aleatorio de 42 para asegurar la reproducibilidad de los datos.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

df = df.dropna()

# Aplicar One-Hot Encoding a las variables categóricas
categorical_columns = ['EPS', 'SEXO', 'DPTO', 'V8', 'Grupo_Edad', 'Zona']
encoder = OneHotEncoder()
encoded_categoricals = encoder.fit_transform(df[categorical_columns])
encoded_df = pd.DataFrame(encoded_categoricals.toarray(), columns=encoder.get_feature_names_out(categorical_columns), index=df.index)

# Concatenar los datos codificados con el resto del dataframe
df = pd.concat([df.drop(categorical_columns, axis=1), encoded_df], axis=1)

# Dividir el conjunto de datos en entrenamiento y prueba
X = df.drop('Valor_Neto', axis=1)
y = df['Valor_Neto']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, shuffle=True)

# %% [markdown]
# Se lleva a cabo la inicialización, entrenamiento y evaluación de múltiples modelos de regresión, como Regresión Lineal, Árbol de Decisión, Bosque Aleatorio y XGBoost, con el objetivo de establecer una línea base de métricas de desempeño. Al utilizar varios modelos, se facilita la comparación directa de su rendimiento en el mismo conjunto de datos, lo que permite identificar cuál modelo ofrece la mejor precisión y generalización. Para cada modelo, se calculan y registran métricas clave como el coeficiente de determinación (R2), el error absoluto medio (MAE) y el error cuadrático medio (MSE) tanto en el conjunto de entrenamiento como en el de prueba.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Inicializar los modelos
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'XGBoost': XGBRegressor(verbosity=0)
}

# Entrenar y evaluar los modelos
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    results[name] = {
        'train': {
            'R2': r2_score(y_train, y_train_pred),
            'MAE': mean_absolute_error(y_train, y_train_pred),
            'MSE': mean_squared_error(y_train, y_train_pred)
        },
        'test': {
            'R2': r2_score(y_test, y_test_pred),
            'MAE': mean_absolute_error(y_test, y_test_pred),
            'MSE': mean_squared_error(y_test, y_test_pred)
        }
    }

# Imprimir resultados
for model_name, metrics in results.items():
    print(f"Modelo: {model_name}")
    for dataset_type, values in metrics.items():
        print(f"\t{dataset_type} Metrics:")
        for metric_name, metric_value in values.items():
            print(f"\t\t{metric_name}: {metric_value:.4f}")
# Out:
# Modelo: Linear Regression
# 	train Metrics:
# 		R2: 0.0427
# 		MAE: 145286.1754
# 		MSE: 231967534040.7825
# 	test Metrics:
# 		R2: -241445910.0610
# 		MAE: 20848791.0509
# 		MSE: 68094847308776226816.0000
# Modelo: Decision Tree
# 	train Metrics:
# 		R2: 1.0000
# 		MAE: 0.0000
# 		MSE: 0.0000
# 	test Metrics:
# 		R2: -0.2354
# 		MAE: 130419.1630
# 		MSE: 348415973265.7783
# Modelo: Random Forest
# 	train Metrics:
# 		R2: 0.8629
# 		MAE: 38192.4211
# 		MSE: 33216458831.3307
# 	test Metrics:
# 		R2: 0.1384
# 		MAE: 102000.2117
# 		MSE: 242986601574.2516
# Modelo: XGBoost
# 	train Metrics:
# 		R2: 0.5690
# 		MAE: 90749.8897
# 		MSE: 104435125033.2767
# 	test Metrics:
# 		R2: -0.0108
# 		MAE: 97372.7589
# 		MSE: 285067909227.2698

# %% [markdown]
# Al evaluar los modelos con datos privatizados, tanto la Regresión Lineal como el Árbol de Decisión enfrentan problemas significativos, con el Árbol mostrando un claro overfitting. Dado esto, XGBoost es  la opción más importante debido a su flexibilidad y robustez.
#
# Usando Optuna para afinar XGBoost, se busca mejorar significativamente su rendimiento, equilibrando la precisión en el entrenamiento con la capacidad de generalizar bien en nuevos datos. Esta búsqueda de hiperparámetros no solo mejora la precisión del modelo, sino que también adapta el modelo proporcionando un balance entre ajuste y generalización.

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

def objective(trial):
    param = {
        'verbosity': 0,
        'objective': 'reg:squarederror',
        'tree_method': 'exact',  # para modelos más pequeños, 'exact' es adecuado
        'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }
    
    model = XGBRegressor(**param)
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False, early_stopping_rounds=50)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    return r2

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=40)

best_params = study.best_params
print("Mejores parámetros:", best_params)

# Entrenar el modelo con los mejores parámetros
optimized_model = XGBRegressor(**best_params)
optimized_model.fit(X_train, y_train)

# Evaluación del modelo
y_train_pred = optimized_model.predict(X_train)
y_test_pred = optimized_model.predict(X_test)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print(f"R2 Train: {train_r2:.4f}")
print(f"R2 Test: {test_r2:.4f}")
# Out:
# [I 2024-05-18 11:41:05,717] A new study created in memory with name: no-name-21112354-a8d6-4d79-a7bf-e99cf8840225
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:41:24,907] Trial 0 finished with value: 0.16999465861076446 and parameters: {'lambda': 0.0020807135351318786, 'alpha': 6.971932384745401e-06, 'colsample_bytree': 0.3661400454795757, 'subsample': 0.3091914651792297, 'learning_rate': 0.08488780494330916, 'n_estimators': 893, 'max_depth': 11, 'min_child_weight': 110}. Best is trial 0 with value: 0.16999465861076446.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:41:50,452] Trial 1 finished with value: 0.17082316884670823 and parameters: {'lambda': 4.110303283795235e-06, 'alpha': 7.396180060008153e-05, 'colsample_bytree': 0.7761347905841388, 'subsample': 0.9136473438573357, 'learning_rate': 0.05593071252022113, 'n_estimators': 535, 'max_depth': 9, 'min_child_weight': 261}. Best is trial 1 with value: 0.17082316884670823.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:42:15,586] Trial 2 finished with value: 0.1718177849252518 and parameters: {'lambda': 4.727572376460203e-06, 'alpha': 0.0003161761493138197, 'colsample_bytree': 0.17357969949254, 'subsample': 0.9796565462213135, 'learning_rate': 0.07562043448421338, 'n_estimators': 613, 'max_depth': 10, 'min_child_weight': 47}. Best is trial 2 with value: 0.1718177849252518.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:42:39,854] Trial 3 finished with value: 0.16721299040454218 and parameters: {'lambda': 0.021327540245451537, 'alpha': 0.005564694658807615, 'colsample_bytree': 0.20842695314466309, 'subsample': 0.6503840822775344, 'learning_rate': 0.0460718989041903, 'n_estimators': 263, 'max_depth': 10, 'min_child_weight': 85}. Best is trial 2 with value: 0.1718177849252518.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:43:23,338] Trial 4 finished with value: 0.16879771889527206 and parameters: {'lambda': 1.0689616464006782e-05, 'alpha': 0.7558884006793843, 'colsample_bytree': 0.8508150439733846, 'subsample': 0.3900952989749291, 'learning_rate': 0.04846115501654674, 'n_estimators': 118, 'max_depth': 20, 'min_child_weight': 232}. Best is trial 2 with value: 0.1718177849252518.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:43:55,522] Trial 5 finished with value: 0.17238742552236752 and parameters: {'lambda': 3.393422559451241e-05, 'alpha': 0.001956409133028582, 'colsample_bytree': 0.9866408024527931, 'subsample': 0.23667043842089386, 'learning_rate': 0.051972190536555676, 'n_estimators': 173, 'max_depth': 16, 'min_child_weight': 108}. Best is trial 5 with value: 0.17238742552236752.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:44:32,657] Trial 6 finished with value: 0.17445862490635677 and parameters: {'lambda': 0.0050956496329554925, 'alpha': 5.356235632225121e-06, 'colsample_bytree': 0.8861522584828703, 'subsample': 0.23497545832835492, 'learning_rate': 0.056971513294836226, 'n_estimators': 758, 'max_depth': 19, 'min_child_weight': 50}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:44:42,705] Trial 7 finished with value: 0.1606282619359206 and parameters: {'lambda': 4.418263853895375e-05, 'alpha': 1.784242067371752e-06, 'colsample_bytree': 0.6374952198944146, 'subsample': 0.10529251035629413, 'learning_rate': 0.07445258875155407, 'n_estimators': 884, 'max_depth': 4, 'min_child_weight': 269}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:45:11,585] Trial 8 finished with value: 0.16892397032831974 and parameters: {'lambda': 8.472647374586771e-06, 'alpha': 0.0028312188816423454, 'colsample_bytree': 0.47495979985917214, 'subsample': 0.5793630645616568, 'learning_rate': 0.03730538276300302, 'n_estimators': 586, 'max_depth': 3, 'min_child_weight': 227}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:45:58,022] Trial 9 finished with value: 0.1706696802169705 and parameters: {'lambda': 0.024826730487162593, 'alpha': 6.033381447336782e-06, 'colsample_bytree': 0.41537844164295024, 'subsample': 0.4427113525019123, 'learning_rate': 0.03737431369283361, 'n_estimators': 693, 'max_depth': 19, 'min_child_weight': 81}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:47:01,593] Trial 10 finished with value: 0.13094320964719453 and parameters: {'lambda': 4.9477177767995125e-08, 'alpha': 2.7587729871067482e-08, 'colsample_bytree': 0.7100096643160619, 'subsample': 0.7845322444435112, 'learning_rate': 0.01221833772627863, 'n_estimators': 383, 'max_depth': 16, 'min_child_weight': 3}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:47:27,186] Trial 11 finished with value: 0.16595052992139714 and parameters: {'lambda': 0.3683645004241109, 'alpha': 0.10375422404481624, 'colsample_bytree': 0.976636195720502, 'subsample': 0.11730065227011073, 'learning_rate': 0.059979233993275885, 'n_estimators': 771, 'max_depth': 15, 'min_child_weight': 167}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:48:36,839] Trial 12 finished with value: 0.1710270308807217 and parameters: {'lambda': 0.001675459532505197, 'alpha': 1.5431522618179162e-08, 'colsample_bytree': 0.9978290769264426, 'subsample': 0.2727044536425345, 'learning_rate': 0.02701312623125363, 'n_estimators': 419, 'max_depth': 16, 'min_child_weight': 156}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:48:53,066] Trial 13 finished with value: 0.16928384731826485 and parameters: {'lambda': 0.0005290513655944656, 'alpha': 4.6020759428569386e-07, 'colsample_bytree': 0.8764124298883277, 'subsample': 0.24352225544063846, 'learning_rate': 0.09962382418582999, 'n_estimators': 161, 'max_depth': 14, 'min_child_weight': 12}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:49:34,306] Trial 14 finished with value: 0.17118782595590365 and parameters: {'lambda': 1.5884749586140814e-07, 'alpha': 0.0001329370178985681, 'colsample_bytree': 0.6416983238540863, 'subsample': 0.4649413344031058, 'learning_rate': 0.06451337729987235, 'n_estimators': 966, 'max_depth': 18, 'min_child_weight': 122}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:49:56,439] Trial 15 finished with value: 0.1729156327945065 and parameters: {'lambda': 0.00017381399247964565, 'alpha': 0.0037889589293294613, 'colsample_bytree': 0.8749906303948611, 'subsample': 0.2049173713759296, 'learning_rate': 0.07109351499183443, 'n_estimators': 761, 'max_depth': 13, 'min_child_weight': 39}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:50:07,042] Trial 16 finished with value: 0.17427993786137586 and parameters: {'lambda': 0.7557580738928549, 'alpha': 0.058104924038733144, 'colsample_bytree': 0.8236398565261931, 'subsample': 0.17609331722287444, 'learning_rate': 0.07174629697822343, 'n_estimators': 769, 'max_depth': 7, 'min_child_weight': 49}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:50:16,112] Trial 17 finished with value: 0.16706436109836387 and parameters: {'lambda': 0.9574636761131231, 'alpha': 0.1875177051326146, 'colsample_bytree': 0.5588457108689993, 'subsample': 0.3864039079496264, 'learning_rate': 0.09080500108544438, 'n_estimators': 800, 'max_depth': 6, 'min_child_weight': 48}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:50:32,996] Trial 18 finished with value: 0.1725830028750278 and parameters: {'lambda': 0.06949841360377097, 'alpha': 2.600785977195083e-07, 'colsample_bytree': 0.7579224701743627, 'subsample': 0.582336049007823, 'learning_rate': 0.08373835694643003, 'n_estimators': 673, 'max_depth': 7, 'min_child_weight': 180}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:50:47,193] Trial 19 finished with value: 0.17164776114837077 and parameters: {'lambda': 0.10666507838884688, 'alpha': 1.7902378874861117e-05, 'colsample_bytree': 0.8366957714389623, 'subsample': 0.15999857027560166, 'learning_rate': 0.06858440543084032, 'n_estimators': 490, 'max_depth': 7, 'min_child_weight': 76}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:51:15,183] Trial 20 finished with value: 0.16484156009735884 and parameters: {'lambda': 0.005552463994931871, 'alpha': 0.022961066153445547, 'colsample_bytree': 0.6405867867087576, 'subsample': 0.3241412163603047, 'learning_rate': 0.04014540219428943, 'n_estimators': 992, 'max_depth': 12, 'min_child_weight': 27}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:51:41,280] Trial 21 finished with value: 0.1724972107073135 and parameters: {'lambda': 0.00027643131914006246, 'alpha': 0.020688456679046528, 'colsample_bytree': 0.9073574375563451, 'subsample': 0.19429049046727423, 'learning_rate': 0.06838356246547674, 'n_estimators': 721, 'max_depth': 13, 'min_child_weight': 46}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:52:07,189] Trial 22 finished with value: 0.17438950396857844 and parameters: {'lambda': 0.00024344107934938901, 'alpha': 0.0008294465563239774, 'colsample_bytree': 0.7892659965573731, 'subsample': 0.18493918842547707, 'learning_rate': 0.07722232235540416, 'n_estimators': 846, 'max_depth': 18, 'min_child_weight': 66}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:52:35,595] Trial 23 finished with value: 0.17108156275352637 and parameters: {'lambda': 0.007403659921041069, 'alpha': 0.0003373453061110774, 'colsample_bytree': 0.7431272304069004, 'subsample': 0.33417092765549805, 'learning_rate': 0.08074730139036182, 'n_estimators': 852, 'max_depth': 18, 'min_child_weight': 70}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:53:30,145] Trial 24 finished with value: 0.17155777837508168 and parameters: {'lambda': 5.888617907930881e-07, 'alpha': 5.9955745245026014e-05, 'colsample_bytree': 0.7902124274935616, 'subsample': 0.4973382321358958, 'learning_rate': 0.059423764673681864, 'n_estimators': 844, 'max_depth': 18, 'min_child_weight': 105}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:54:18,236] Trial 25 finished with value: 0.16956097798737946 and parameters: {'lambda': 0.0007917157201640816, 'alpha': 0.0007419785271098492, 'colsample_bytree': 0.9250435342210738, 'subsample': 0.1448912487617255, 'learning_rate': 0.09584967134408964, 'n_estimators': 648, 'max_depth': 20, 'min_child_weight': 134}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:54:29,238] Trial 26 finished with value: 0.16449638584033255 and parameters: {'lambda': 0.16516536288166742, 'alpha': 0.02671012672689807, 'colsample_bytree': 0.6828855647733305, 'subsample': 0.7094132960251673, 'learning_rate': 0.07833999835957318, 'n_estimators': 938, 'max_depth': 5, 'min_child_weight': 68}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:54:50,825] Trial 27 finished with value: 0.16612659378774064 and parameters: {'lambda': 0.024457359112149562, 'alpha': 0.802165650172005, 'colsample_bytree': 0.5237147751256418, 'subsample': 0.3882008952839907, 'learning_rate': 0.09005570074428693, 'n_estimators': 799, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:55:25,461] Trial 28 finished with value: 0.1717748155368839 and parameters: {'lambda': 6.322177817810408e-05, 'alpha': 1.9095755534376997e-05, 'colsample_bytree': 0.8175213996444004, 'subsample': 0.20233680157247838, 'learning_rate': 0.06337550187156984, 'n_estimators': 717, 'max_depth': 17, 'min_child_weight': 92}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:55:45,435] Trial 29 finished with value: 0.16848408517299762 and parameters: {'lambda': 0.0014714066255967374, 'alpha': 2.509306476001434e-06, 'colsample_bytree': 0.3157944339507943, 'subsample': 0.283423703164048, 'learning_rate': 0.09052717992019345, 'n_estimators': 923, 'max_depth': 11, 'min_child_weight': 135}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:56:54,683] Trial 30 finished with value: 0.16896846172824487 and parameters: {'lambda': 0.004663474450145049, 'alpha': 2.845021592295479e-07, 'colsample_bytree': 0.928748761589403, 'subsample': 0.32400721958173284, 'learning_rate': 0.028955987933386135, 'n_estimators': 844, 'max_depth': 20, 'min_child_weight': 297}. Best is trial 6 with value: 0.17445862490635677.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:57:17,946] Trial 31 finished with value: 0.17545364339509917 and parameters: {'lambda': 0.00024701594556858855, 'alpha': 0.007821328116371975, 'colsample_bytree': 0.8762333637859853, 'subsample': 0.20152504325518536, 'learning_rate': 0.07130613535664129, 'n_estimators': 779, 'max_depth': 13, 'min_child_weight': 39}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:57:34,980] Trial 32 finished with value: 0.1730185654312636 and parameters: {'lambda': 1.0219733148890666e-06, 'alpha': 0.013623446480535614, 'colsample_bytree': 0.8021565056535089, 'subsample': 0.1691928774231944, 'learning_rate': 0.08521942540477394, 'n_estimators': 894, 'max_depth': 14, 'min_child_weight': 29}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:57:47,571] Trial 33 finished with value: 0.17017033641998947 and parameters: {'lambda': 0.0005079556003763719, 'alpha': 0.09272947753058434, 'colsample_bytree': 0.925888637121514, 'subsample': 0.10557171021608502, 'learning_rate': 0.05458504772226605, 'n_estimators': 564, 'max_depth': 9, 'min_child_weight': 58}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:58:01,977] Trial 34 finished with value: 0.16901769097103847 and parameters: {'lambda': 0.0001688497932429319, 'alpha': 0.0011064828773496647, 'colsample_bytree': 0.7241180891511978, 'subsample': 0.232955915604901, 'learning_rate': 0.07414153898128643, 'n_estimators': 647, 'max_depth': 11, 'min_child_weight': 23}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:58:31,718] Trial 35 finished with value: 0.17260127313676887 and parameters: {'lambda': 2.050223789049895e-05, 'alpha': 0.007693293975770102, 'colsample_bytree': 0.8399772316410712, 'subsample': 0.2695898712538855, 'learning_rate': 0.06576460421262488, 'n_estimators': 738, 'max_depth': 19, 'min_child_weight': 58}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:58:55,750] Trial 36 finished with value: 0.16495894584403448 and parameters: {'lambda': 0.013214474502548864, 'alpha': 0.0001947110136571891, 'colsample_bytree': 0.7728583724989959, 'subsample': 0.8379133235645229, 'learning_rate': 0.0607176984891098, 'n_estimators': 810, 'max_depth': 9, 'min_child_weight': 93}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 11:59:18,900] Trial 37 finished with value: 0.15664987625733162 and parameters: {'lambda': 1.6683736999845547e-06, 'alpha': 4.084865309952915e-05, 'colsample_bytree': 0.10044344505304492, 'subsample': 0.9849806877703682, 'learning_rate': 0.04617324961133996, 'n_estimators': 503, 'max_depth': 10, 'min_child_weight': 39}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 12:00:03,114] Trial 38 finished with value: 0.170826630148334 and parameters: {'lambda': 0.0032953423795518237, 'alpha': 0.0006585469126794373, 'colsample_bytree': 0.9617287355414207, 'subsample': 0.3403225768430928, 'learning_rate': 0.051974145004588794, 'n_estimators': 607, 'max_depth': 15, 'min_child_weight': 189}. Best is trial 31 with value: 0.17545364339509917.
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# /var/folders/tv/6r5469xx31vbksvh_943nnr1bcv0mh/T/ipykernel_48795/1286862207.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-05-18 12:00:31,760] Trial 39 finished with value: 0.1683247090108798 and parameters: {'lambda': 0.00010699969254245044, 'alpha': 0.23701700680828416, 'colsample_bytree': 0.5882912036910466, 'subsample': 0.1600766684825005, 'learning_rate': 0.0735409905113545, 'n_estimators': 895, 'max_depth': 17, 'min_child_weight': 98}. Best is trial 31 with value: 0.17545364339509917.
# Mejores parámetros: {'lambda': 0.00024701594556858855, 'alpha': 0.007821328116371975, 'colsample_bytree': 0.8762333637859853, 'subsample': 0.20152504325518536, 'learning_rate': 0.07130613535664129, 'n_estimators': 779, 'max_depth': 13, 'min_child_weight': 39}
# R2 Train: 0.3011
# R2 Test: 0.1271

# %% [markdown]
# La optimización mediante Optuna ha ajustado los parámetros clave de XGBoost, llevando el R2 en el entrenamiento a 0.3011 y en la prueba a 0.1271. Aunque estos números son una mejora, todavía hay una brecha entre cómo el modelo se comporta en los datos de entrenamiento y prueba, lo que indica que podemos seguir ajustando para alcanzar un mejor equilibrio y precisión. Esta búsqueda de hiperparámetros es un paso positivo hacia hacer el modelo más efectivo en escenarios reales con datos privatizados.

# %%
with open('model_priv1.pkl', 'wb') as file:
    pickle.dump(optimized_model, file)
